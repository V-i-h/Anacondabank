# %% [markdown]
# https://raw.githubusercontent.com/romulosilvestre/semanaclassificacao-parte2/refs/heads/master/datasets/anacondabank_credit_scoring.csv

# %%
url = 'https://raw.githubusercontent.com/romulosilvestre/semanaclassificacao-parte2/refs/heads/master/datasets/anacondabank_credit_scoring.csv'

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\vitória\anacondabank_m\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\vitória\anacondabank_m\venv\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\vitória\anacondabank_m\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\vitória\anacondabank_m\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\vitória\anacondabank_m\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\vitória\anacondabank_m\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    default       conta_corrente  prazo_emprestimo_meses  \
# 0        0               < 0 DM                       6
# 1        1    0 <= ... < 200 DM                      48
# 2        0  no checking account                      12
# 3        0               < 0 DM                      42
# 4        1               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# 4                     car (new)              4870
#
#                     reserva_cc tempo_emprego_atual  taxa_comp_salario  \
# 0  unknown/ no savings account       .. >= 7 years                  4
# 1                 ... < 100 DM  1 <= ... < 4 years                  2
# 2                 ... < 100 DM  4 <= ... < 7 years                  2
# 3                 ... < 100 DM  4 <= ... < 7 years                  2
# 4                 ... < 100 DM  1 <= ... < 4 years                  3
#
#                         sexo_est_civil  ... anos_residencia_atual  \
# 0                        male : single  ...                     4
# 1  female : divorced/separated/married  ...                     2
# 2                        male : single  ...                     3
# 3                        male : single  ...                     4
# 4                        male : single  ...                     4
#
#                                          propriedade idade  \
# 0                                        real estate    67
# 1                                        real estate    22
# 2                                        real estate    49
# 3  if not A121 : building society savings agreeme...    45
# 4                              unknown / no property    53
#
#    outros_planos_financiamento tipo_residencia n_creditos_banco  \
# 0                         none             own                2
# 1                         none             own                1
# 2                         none             own                1
# 3                         none        for free                1
# 4                         none        for free                2
#
#                 status_emprego n_dependentes  \
# 0  skilled employee / official             1
# 1  skilled employee / official             1
# 2         unskilled - resident             2
# 3  skilled employee / official             2
# 4  skilled employee / official             2
#
#                                     telefone trabalhador_estrangeiro
# 0  yes, registered under the customers name                      yes
# 1                                       none                     yes
# 2                                       none                     yes
# 3                                       none                     yes
# 4                                       none                     yes
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['default', 'conta_corrente', 'prazo_emprestimo_meses',
#        'historico_credito', 'proposito_emprestimo', 'valor_emprestimo',
#        'reserva_cc', 'tempo_emprego_atual', 'taxa_comp_salario',
#        'sexo_est_civil', 'outros_fiadores', 'anos_residencia_atual',
#        'propriedade', 'idade', 'outros_planos_financiamento',
#        'tipo_residencia', 'n_creditos_banco', 'status_emprego',
#        'n_dependentes', 'telefone', 'trabalhador_estrangeiro'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   default                      1000 non-null   int64
#  1   conta_corrente               1000 non-null   object
#  2   prazo_emprestimo_meses       1000 non-null   int64
#  3   historico_credito            1000 non-null   object
#  4   proposito_emprestimo         1000 non-null   object
#  5   valor_emprestimo             1000 non-null   int64
#  6   reserva_cc                   1000 non-null   object
#  7   tempo_emprego_atual          1000 non-null   object
#  8   taxa_comp_salario            1000 non-null   int64
#  9   sexo_est_civil               1000 non-null   object
#  10  outros_fiadores              1000 non-null   object
#  11  anos_residencia_atual        1000 non-null   int64
#  12  propriedade                  1000 non-null   object
#  13  idade                        1000 non-null   int64
#  14  outros_planos_financiamento  1000 non-null   object
#  15  tipo_residencia              1000 non-null   object
#  16  n_creditos_banco             1000 non-null   int64
#  17  status_emprego               1000 non-null   object
#  18  n_dependentes                1000 non-null   int64
#  19  telefone                     1000 non-null   object
#  20  trabalhador_estrangeiro      1000 non-null   object
# dtypes: int64(8), object(13)
# memory usage: 164.2+ KB

# %%
df['conta_corrente'].unique()
# Out:
# array(['< 0 DM', '0 <= ... < 200 DM', 'no checking account',
#        '>= 200 DM / salary assignments for at least 1 year'], dtype=object)

# %%
dict_c2 ={
    '< 0 DM':1,
    '0 <= ... < 200 DM':2,
    'no checking account':3,
    '>= 200 DM / salary assignments for at least 1 year':4
}

# %%
df['conta_corrente']= df['conta_corrente'].map(dict_c2)

# %%
df
# Out:
#      default  conta_corrente  prazo_emprestimo_meses  \
# 0          0               1                       6
# 1          1               2                      48
# 2          0               3                      12
# 3          0               1                      42
# 4          1               1                      24
# ..       ...             ...                     ...
# 995        0               3                      12
# 996        0               1                      30
# 997        0               3                      12
# 998        1               1                      45
# 999        0               2                      45
#
#                                      historico_credito  \
# 0    critical account/ other credits existing (not ...
# 1             existing credits paid back duly till now
# 2    critical account/ other credits existing (not ...
# 3             existing credits paid back duly till now
# 4                      delay in paying off in the past
# ..                                                 ...
# 995           existing credits paid back duly till now
# 996           existing credits paid back duly till now
# 997           existing credits paid back duly till now
# 998           existing credits paid back duly till now
# 999  critical account/ other credits existing (not ...
#
#              proposito_emprestimo  valor_emprestimo  \
# 0             domestic appliances              1169
# 1             domestic appliances              5951
# 2    (vacation - does not exist?)              2096
# 3                radio/television              7882
# 4                       car (new)              4870
# ..                            ...               ...
# 995              radio/television              1736
# 996                    car (used)              3857
# 997           domestic appliances               804
# 998           domestic appliances              1845
# 999                    car (used)              4576
#
#                       reserva_cc tempo_emprego_atual  taxa_comp_salario  \
# 0    unknown/ no savings account       .. >= 7 years                  4
# 1                   ... < 100 DM  1 <= ... < 4 years                  2
# 2                   ... < 100 DM  4 <= ... < 7 years                  2
# 3                   ... < 100 DM  4 <= ... < 7 years                  2
# 4                   ... < 100 DM  1 <= ... < 4 years                  3
# ..                           ...                 ...                ...
# 995                 ... < 100 DM  4 <= ... < 7 years                  3
# 996                 ... < 100 DM  1 <= ... < 4 years                  4
# 997                 ... < 100 DM       .. >= 7 years                  4
# 998                 ... < 100 DM  1 <= ... < 4 years                  4
# 999          100 <= ... < 500 DM          unemployed                  3
#
#                           sexo_est_civil  ... anos_residencia_atual  \
# 0                          male : single  ...                     4
# 1    female : divorced/separated/married  ...                     2
# 2                          male : single  ...                     3
# 3                          male : single  ...                     4
# 4                          male : single  ...                     4
# ..                                   ...  ...                   ...
# 995  female : divorced/separated/married  ...                     4
# 996            male : divorced/separated  ...                     4
# 997                        male : single  ...                     4
# 998                        male : single  ...                     4
# 999                        male : single  ...                     4
#
#                                            propriedade idade  \
# 0                                          real estate    67
# 1                                          real estate    22
# 2                                          real estate    49
# 3    if not A121 : building society savings agreeme...    45
# 4                                unknown / no property    53
# ..                                                 ...   ...
# 995                                        real estate    31
# 996  if not A121 : building society savings agreeme...    40
# 997  if not A121/A122 : car or other, not in attrib...    38
# 998                              unknown / no property    23
# 999  if not A121/A122 : car or other, not in attrib...    27
#
#      outros_planos_financiamento tipo_residencia n_creditos_banco  \
# 0                           none             own                2
# 1                           none             own                1
# 2                           none             own                1
# 3                           none        for free                1
# 4                           none        for free                2
# ..                           ...             ...              ...
# 995                         none             own                1
# 996                         none             own                1
# 997                         none             own                1
# 998                         none        for free                1
# 999                         none             own                1
#
#                                         status_emprego n_dependentes  \
# 0                          skilled employee / official             1
# 1                          skilled employee / official             1
# 2                                 unskilled - resident             2
# 3                          skilled employee / official             2
# 4                          skilled employee / official             2
# ..                                                 ...           ...
# 995                               unskilled - resident             1
# 996  management/ self-employed/ highly qualified em...             1
# 997                        skilled employee / official             1
# 998                        skilled employee / official             1
# 999                        skilled employee / official             1
#
#                                       telefone trabalhador_estrangeiro
# 0    yes, registered under the customers name                      yes
# 1                                         none                     yes
# 2                                         none                     yes
# 3                                         none                     yes
# 4                                         none                     yes
# ..                                         ...                     ...
# 995                                       none                     yes
# 996  yes, registered under the customers name                      yes
# 997                                       none                     yes
# 998  yes, registered under the customers name                      yes
# 999                                       none                     yes
#
# [1000 rows x 21 columns]

# %%
df['historico_credito'].unique()
# Out:
# array(['critical account/ other credits existing (not at this bank)',
#        'existing credits paid back duly till now',
#        'delay in paying off in the past',
#        'no credits taken/ all credits paid back duly',
#        'all credits at this bank paid back duly'], dtype=object)

# %%
dict_historico= {
    'critical account/ other credits existing (not at this bank)':1,
    'existing credits paid back duly till now':2,
    'delay in paying off in the past':3,
    'no credits taken/ all credits paid back duly':4,
    'all credits at this bank paid back duly':5
}

# %%
df['historico_credito']= df['historico_credito'].map(dict_historico)

# %%
df
# Out:
#      default  conta_corrente  prazo_emprestimo_meses  historico_credito  \
# 0          0               1                       6                  1
# 1          1               2                      48                  2
# 2          0               3                      12                  1
# 3          0               1                      42                  2
# 4          1               1                      24                  3
# ..       ...             ...                     ...                ...
# 995        0               3                      12                  2
# 996        0               1                      30                  2
# 997        0               3                      12                  2
# 998        1               1                      45                  2
# 999        0               2                      45                  1
#
#              proposito_emprestimo  valor_emprestimo  \
# 0             domestic appliances              1169
# 1             domestic appliances              5951
# 2    (vacation - does not exist?)              2096
# 3                radio/television              7882
# 4                       car (new)              4870
# ..                            ...               ...
# 995              radio/television              1736
# 996                    car (used)              3857
# 997           domestic appliances               804
# 998           domestic appliances              1845
# 999                    car (used)              4576
#
#                       reserva_cc tempo_emprego_atual  taxa_comp_salario  \
# 0    unknown/ no savings account       .. >= 7 years                  4
# 1                   ... < 100 DM  1 <= ... < 4 years                  2
# 2                   ... < 100 DM  4 <= ... < 7 years                  2
# 3                   ... < 100 DM  4 <= ... < 7 years                  2
# 4                   ... < 100 DM  1 <= ... < 4 years                  3
# ..                           ...                 ...                ...
# 995                 ... < 100 DM  4 <= ... < 7 years                  3
# 996                 ... < 100 DM  1 <= ... < 4 years                  4
# 997                 ... < 100 DM       .. >= 7 years                  4
# 998                 ... < 100 DM  1 <= ... < 4 years                  4
# 999          100 <= ... < 500 DM          unemployed                  3
#
#                           sexo_est_civil  ... anos_residencia_atual  \
# 0                          male : single  ...                     4
# 1    female : divorced/separated/married  ...                     2
# 2                          male : single  ...                     3
# 3                          male : single  ...                     4
# 4                          male : single  ...                     4
# ..                                   ...  ...                   ...
# 995  female : divorced/separated/married  ...                     4
# 996            male : divorced/separated  ...                     4
# 997                        male : single  ...                     4
# 998                        male : single  ...                     4
# 999                        male : single  ...                     4
#
#                                            propriedade idade  \
# 0                                          real estate    67
# 1                                          real estate    22
# 2                                          real estate    49
# 3    if not A121 : building society savings agreeme...    45
# 4                                unknown / no property    53
# ..                                                 ...   ...
# 995                                        real estate    31
# 996  if not A121 : building society savings agreeme...    40
# 997  if not A121/A122 : car or other, not in attrib...    38
# 998                              unknown / no property    23
# 999  if not A121/A122 : car or other, not in attrib...    27
#
#      outros_planos_financiamento tipo_residencia n_creditos_banco  \
# 0                           none             own                2
# 1                           none             own                1
# 2                           none             own                1
# 3                           none        for free                1
# 4                           none        for free                2
# ..                           ...             ...              ...
# 995                         none             own                1
# 996                         none             own                1
# 997                         none             own                1
# 998                         none        for free                1
# 999                         none             own                1
#
#                                         status_emprego n_dependentes  \
# 0                          skilled employee / official             1
# 1                          skilled employee / official             1
# 2                                 unskilled - resident             2
# 3                          skilled employee / official             2
# 4                          skilled employee / official             2
# ..                                                 ...           ...
# 995                               unskilled - resident             1
# 996  management/ self-employed/ highly qualified em...             1
# 997                        skilled employee / official             1
# 998                        skilled employee / official             1
# 999                        skilled employee / official             1
#
#                                       telefone trabalhador_estrangeiro
# 0    yes, registered under the customers name                      yes
# 1                                         none                     yes
# 2                                         none                     yes
# 3                                         none                     yes
# 4                                         none                     yes
# ..                                         ...                     ...
# 995                                       none                     yes
# 996  yes, registered under the customers name                      yes
# 997                                       none                     yes
# 998  yes, registered under the customers name                      yes
# 999                                       none                     yes
#
# [1000 rows x 21 columns]

# %%
df['proposito_emprestimo'].unique()

dict_pe = {
    'domestic appliances':1,
    '(vacation - does not exist?)':2,
    'radio/television':3,
    'car (new)':4,
    'car (used)':5,
    'business':6,
    'repairs':7,
    'education':8,
    'furniture/equipment':9,
    'retraining':10

}

df['proposito_emprestimo'] = df['proposito_emprestimo'].map(dict_pe)

# %%
df["reserva_cc"].unique()

dict_rcc = {
    "unknown/ no savings account":0,
    "... < 100 DM":1,
    "500 <= ... < 1000 DM ":2,
    ".. >= 1000 DM ":3,
    "100 <= ... < 500 DM":4,
}

df["reserva_cc"] = df["reserva_cc"].map(dict_rcc)

# %%
#unique
df['sexo_est_civil'].unique()
#dicionário
sexo_est_civil ={
    'male : single':1,
    'female : divorced/separated/married':2,
    'male : divorced/separated':3,
    'male : married/widowed':4
}
#map
df['sexo_est_civil']=df['sexo_est_civil'].map(sexo_est_civil)

# %%
df['outros_planos_financiamento'].unique()

dict_opf = {
    'none':1,
    'bank':2,
    'stores':3
}

df['outros_planos_financiamento'] = df['outros_planos_financiamento'].map(dict_opf)

# %%
#unique
df['tipo_residencia'].unique()

#dicionário
dict_tr = {
    'own':1,
    'for free':2,
    'rent':3,
}
#map
df['tipo_residencia'] =df['tipo_residencia'].map(dict_tr)

# %%
#unique
df['status_emprego'].unique()

#dicionário
dict_status_emprego = {
    'skilled employee / official':1,
    'unskilled - resident':2,
    'management/ self-employed/ highly qualified employee/ officer':3,
    'unemployed/ unskilled - non-resident':4}

#map
df['status_emprego'] = df['status_emprego'].map(dict_status_emprego)

# %%
#unique
df['telefone'].unique()

#dicionário
dict_tel = {
    'none':0,
    'yes, registered under the customers name ':1,
}

#map
df['telefone'] = df['telefone'].map(dict_tel)

# %%
#unique
df['trabalhador_estrangeiro'].unique()

#dicionário
dict_te = {
    'no':0,
    'yes':1,
}

#map
df['trabalhador_estrangeiro'] = df['trabalhador_estrangeiro'].map(dict_te)

# %%
df.head(100)
# Out:
#     default  conta_corrente  prazo_emprestimo_meses  historico_credito  \
# 0         0               1                       6                  1
# 1         1               2                      48                  2
# 2         0               3                      12                  1
# 3         0               1                      42                  2
# 4         1               1                      24                  3
# ..      ...             ...                     ...                ...
# 95        1               2                      54                  4
# 96        0               3                      12                  1
# 97        0               2                      18                  2
# 98        0               2                      36                  1
# 99        0               2                      20                  3
#
#     proposito_emprestimo  valor_emprestimo  reserva_cc tempo_emprego_atual  \
# 0                      1              1169           0       .. >= 7 years
# 1                      1              5951           1  1 <= ... < 4 years
# 2                      2              2096           1  4 <= ... < 7 years
# 3                      3              7882           1  4 <= ... < 7 years
# 4                      4              4870           1  1 <= ... < 4 years
# ..                   ...               ...         ...                 ...
# 95                     6             15945           1       ... < 1 year
# 96                     2              2012           0  4 <= ... < 7 years
# 97                     6              2622           4  1 <= ... < 4 years
# 98                     1              2337           1       .. >= 7 years
# 99                     5              7057           0  4 <= ... < 7 years
#
#     taxa_comp_salario  sexo_est_civil  ... anos_residencia_atual  \
# 0                   4               1  ...                     4
# 1                   2               2  ...                     2
# 2                   2               1  ...                     3
# 3                   2               1  ...                     4
# 4                   3               1  ...                     4
# ..                ...             ...  ...                   ...
# 95                  3               1  ...                     4
# 96                  4               2  ...                     2
# 97                  4               1  ...                     4
# 98                  4               1  ...                     4
# 99                  3               1  ...                     4
#
#                                           propriedade idade  \
# 0                                         real estate    67
# 1                                         real estate    22
# 2                                         real estate    49
# 3   if not A121 : building society savings agreeme...    45
# 4                               unknown / no property    53
# ..                                                ...   ...
# 95                              unknown / no property    58
# 96  if not A121/A122 : car or other, not in attrib...    61
# 97  if not A121/A122 : car or other, not in attrib...    34
# 98                                        real estate    36
# 99  if not A121 : building society savings agreeme...    36
#
#     outros_planos_financiamento  tipo_residencia  n_creditos_banco  \
# 0                             1                1                 2
# 1                             1                1                 1
# 2                             1                1                 1
# 3                             1                2                 1
# 4                             1                2                 2
# ..                          ...              ...               ...
# 95                            1                3                 1
# 96                            1                1                 1
# 97                            1                1                 1
# 98                            1                1                 1
# 99                            2                3                 2
#
#     status_emprego  n_dependentes  telefone  trabalhador_estrangeiro
# 0                1              1         1                        1
# 1                1              1         0                        1
# 2                2              2         0                        1
# 3                1              2         0                        1
# 4                1              2         0                        1
# ..             ...            ...       ...                      ...
# 95               1              1         1                        1
# 96               1              1         0                        1
# 97               1              1         0                        1
# 98               1              1         0                        1
# 99               3              2         1                        1
#
# [100 rows x 21 columns]

# %%
df_object = df.select_dtypes(include=['object'])

df_object.head()


df["outros_fiadores"].unique()
dict_of = {
    "none":1,
    "guarantor":2,
    "co-applicant":3,
}

df["outros_fiadores"] = df["outros_fiadores"].map(dict_of)

# %%
df['tempo_emprego_atual'].unique()

#dicionário
dict_tea = {
    '.. >= 7 years':1,
    '1 <= ... < 4 years':2,
    '4 <= ... < 7 years':3,
    'unemployed':4,
    '... < 1 year ':5
}
#map
df['tempo_emprego_atual'] = df['tempo_emprego_atual'].map(dict_tea)

# %%
df['propriedade'].unique()
# Out:
# array(['real estate',
#        'if not A121 : building society savings agreement/ life insurance',
#        'unknown / no property',
#        'if not A121/A122 : car or other, not in attribute 6'],
#       dtype=object)

# %%
df
# Out:
#      default  conta_corrente  prazo_emprestimo_meses  historico_credito  \
# 0          0               1                       6                  1
# 1          1               2                      48                  2
# 2          0               3                      12                  1
# 3          0               1                      42                  2
# 4          1               1                      24                  3
# ..       ...             ...                     ...                ...
# 995        0               3                      12                  2
# 996        0               1                      30                  2
# 997        0               3                      12                  2
# 998        1               1                      45                  2
# 999        0               2                      45                  1
#
#      proposito_emprestimo  valor_emprestimo  reserva_cc  tempo_emprego_atual  \
# 0                       1              1169           0                    1
# 1                       1              5951           1                    2
# 2                       2              2096           1                    3
# 3                       3              7882           1                    3
# 4                       4              4870           1                    2
# ..                    ...               ...         ...                  ...
# 995                     3              1736           1                    3
# 996                     5              3857           1                    2
# 997                     1               804           1                    1
# 998                     1              1845           1                    2
# 999                     5              4576           4                    4
#
#      taxa_comp_salario  sexo_est_civil  ...  anos_residencia_atual  \
# 0                    4               1  ...                      4
# 1                    2               2  ...                      2
# 2                    2               1  ...                      3
# 3                    2               1  ...                      4
# 4                    3               1  ...                      4
# ..                 ...             ...  ...                    ...
# 995                  3               2  ...                      4
# 996                  4               3  ...                      4
# 997                  4               1  ...                      4
# 998                  4               1  ...                      4
# 999                  3               1  ...                      4
#
#                                            propriedade idade  \
# 0                                          real estate    67
# 1                                          real estate    22
# 2                                          real estate    49
# 3    if not A121 : building society savings agreeme...    45
# 4                                unknown / no property    53
# ..                                                 ...   ...
# 995                                        real estate    31
# 996  if not A121 : building society savings agreeme...    40
# 997  if not A121/A122 : car or other, not in attrib...    38
# 998                              unknown / no property    23
# 999  if not A121/A122 : car or other, not in attrib...    27
#
#      outros_planos_financiamento  tipo_residencia  n_creditos_banco  \
# 0                              1                1                 2
# 1                              1                1                 1
# 2                              1                1                 1
# 3                              1                2                 1
# 4                              1                2                 2
# ..                           ...              ...               ...
# 995                            1                1                 1
# 996                            1                1                 1
# 997                            1                1                 1
# 998                            1                2                 1
# 999                            1                1                 1
#
#      status_emprego  n_dependentes  telefone  trabalhador_estrangeiro
# 0                 1              1         1                        1
# 1                 1              1         0                        1
# 2                 2              2         0                        1
# 3                 1              2         0                        1
# 4                 1              2         0                        1
# ..              ...            ...       ...                      ...
# 995               2              1         0                        1
# 996               3              1         1                        1
# 997               1              1         0                        1
# 998               1              1         1                        1
# 999               1              1         0                        1
#
# [1000 rows x 21 columns]

# %%
#unique
df['propriedade'].unique()
#dicionário
dict_propriedade = {
    'real estate':1,
    'if not A121 : building society savings agreement/ life insurance':2,
    'unknown / no property':3,
    'if not A121/A122 : car or other, not in attribute 6':4
  
}
#map
df['propriedade'] = df['propriedade'].map(dict_propriedade)

# %%
df
# Out:
#      default  conta_corrente  prazo_emprestimo_meses  historico_credito  \
# 0          0               1                       6                  1
# 1          1               2                      48                  2
# 2          0               3                      12                  1
# 3          0               1                      42                  2
# 4          1               1                      24                  3
# ..       ...             ...                     ...                ...
# 995        0               3                      12                  2
# 996        0               1                      30                  2
# 997        0               3                      12                  2
# 998        1               1                      45                  2
# 999        0               2                      45                  1
#
#      proposito_emprestimo  valor_emprestimo  reserva_cc  tempo_emprego_atual  \
# 0                       1              1169           0                    1
# 1                       1              5951           1                    2
# 2                       2              2096           1                    3
# 3                       3              7882           1                    3
# 4                       4              4870           1                    2
# ..                    ...               ...         ...                  ...
# 995                     3              1736           1                    3
# 996                     5              3857           1                    2
# 997                     1               804           1                    1
# 998                     1              1845           1                    2
# 999                     5              4576           4                    4
#
#      taxa_comp_salario  sexo_est_civil  ...  anos_residencia_atual  \
# 0                    4               1  ...                      4
# 1                    2               2  ...                      2
# 2                    2               1  ...                      3
# 3                    2               1  ...                      4
# 4                    3               1  ...                      4
# ..                 ...             ...  ...                    ...
# 995                  3               2  ...                      4
# 996                  4               3  ...                      4
# 997                  4               1  ...                      4
# 998                  4               1  ...                      4
# 999                  3               1  ...                      4
#
#      propriedade  idade  outros_planos_financiamento  tipo_residencia  \
# 0              1     67                            1                1
# 1              1     22                            1                1
# 2              1     49                            1                1
# 3              2     45                            1                2
# 4              3     53                            1                2
# ..           ...    ...                          ...              ...
# 995            1     31                            1                1
# 996            2     40                            1                1
# 997            4     38                            1                1
# 998            3     23                            1                2
# 999            4     27                            1                1
#
#      n_creditos_banco  status_emprego  n_dependentes  telefone  \
# 0                   2               1              1         1
# 1                   1               1              1         0
# 2                   1               2              2         0
# 3                   1               1              2         0
# 4                   2               1              2         0
# ..                ...             ...            ...       ...
# 995                 1               2              1         0
# 996                 1               3              1         1
# 997                 1               1              1         0
# 998                 1               1              1         1
# 999                 1               1              1         0
#
#      trabalhador_estrangeiro
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ..                       ...
# 995                        1
# 996                        1
# 997                        1
# 998                        1
# 999                        1
#
# [1000 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   default                      1000 non-null   int64
#  1   conta_corrente               1000 non-null   int64
#  2   prazo_emprestimo_meses       1000 non-null   int64
#  3   historico_credito            1000 non-null   int64
#  4   proposito_emprestimo         1000 non-null   int64
#  5   valor_emprestimo             1000 non-null   int64
#  6   reserva_cc                   1000 non-null   int64
#  7   tempo_emprego_atual          1000 non-null   int64
#  8   taxa_comp_salario            1000 non-null   int64
#  9   sexo_est_civil               1000 non-null   int64
#  10  outros_fiadores              1000 non-null   int64
#  11  anos_residencia_atual        1000 non-null   int64
#  12  propriedade                  1000 non-null   int64
#  13  idade                        1000 non-null   int64
#  14  outros_planos_financiamento  1000 non-null   int64
#  15  tipo_residencia              1000 non-null   int64
#  16  n_creditos_banco             1000 non-null   int64
#  17  status_emprego               1000 non-null   int64
#  18  n_dependentes                1000 non-null   int64
#  19  telefone                     1000 non-null   int64
#  20  trabalhador_estrangeiro      1000 non-null   int64
# dtypes: int64(21)
# memory usage: 164.2 KB

# %% [markdown]
# # Regressão Logística
